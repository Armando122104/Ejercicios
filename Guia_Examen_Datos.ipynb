# %% [markdown]
# <a href="https://colab.research.google.com/github/Armando122104/Ejercicios/blob/main/Guia_Examen_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Leer Excel
import pandas as pd
# !git clone https://github.com/Armando122104/Ejercicios.git
# Out:
# Cloning into 'Ejercicios'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
