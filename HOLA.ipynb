# %% [markdown]
# <a href="https://colab.research.google.com/github/Armando122104/Ejercicios/blob/main/HOLA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hola')
# Out:
# Hola
